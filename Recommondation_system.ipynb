# %% [markdown]
# #19.10.2022
# Recommendation_Engine Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r"Downloads/Recommendation_Engine Data 1.csv")

# %%
data.head()
# Out:
#         Domain          SKU  SKU's Unique Group ID  \
# 0  Global site  SLSSITAI1001                    SL
# 1  Global site     KDSLP8113                   KDG
# 2  Global site     GHSMV6512                    GH
# 3  Global site    KRSVFKU277                    KR
# 4  Global site    KRSVFKU265                    KR
#
#   Sku's Unique group Id Definition  Customer ID brand Name              Type  \
# 0                    Salwar Kameez       582222     Market     Churidar Suit
# 1                            Girls       620497     Market   Girls Skirt Set
# 2                         Lehengas       620497     Market  Fish Cut Lehenga
# 3                           Kurtis       348096     Market        Long Kurti
# 4                           Kurtis       348096     Market        Long Kurti
#
#                          Art style Product style Added to Cart Date  ...  \
# 0                   Embroidered |            NaN           1-Mar-19  ...
# ...

# %%
data.shape
# Out:
# (61931, 39)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61931 entries, 0 to 61930
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Domain                              61931 non-null  object
#  1   SKU                                 61931 non-null  object
#  2   SKU's Unique Group ID               61931 non-null  object
#  3   Sku's Unique group Id Definition    61931 non-null  object
#  4   Customer ID                         61931 non-null  int64
#  5   brand Name                          61931 non-null  object
#  6   Type                                61931 non-null  object
#  7   Art style                           56198 non-null  object
#  8   Product style                       13508 non-null  object
#  9   Added to Cart Date                  61931 non-null  object
#  10  Added to Cart Time                  61931 non-null  object
# ...

# %%
data.describe()
# Out:
#          Customer ID  Body height  Waist To Floor size  SleeveLength  \
# count   61931.000000  9120.000000           557.000000    365.000000
# mean   462336.018763     4.960633            24.522442      9.052055
# std    198101.475572     0.271107            19.240478      7.211486
# min      6176.000000     4.000000             0.000000      0.000000
# 25%    307340.000000     5.010000             0.000000      0.000000
# 50%    550679.000000     5.030000            37.500000      9.000000
# 75%    632107.000000     5.050000            40.000000     15.000000
# max    657193.000000     6.050000            46.000000     25.000000
#
#        Blouse Length  Blouse NeckStyle
# count     255.000000             255.0
# mean       14.113725               0.0
# std         3.204145               0.0
# min         0.000000               0.0
# 25%        13.500000               0.0
# 50%        15.000000               0.0
# 75%        16.000000               0.0
# ...

# %%
data.isnull().sum()
# Out:
# Domain                                    0
# SKU                                       0
# SKU's Unique Group ID                     0
# Sku's Unique group Id Definition          0
# Customer ID                               0
# brand Name                                0
# Type                                      0
# Art style                              5733
# Product style                         48423
# Added to Cart Date                        0
# Added to Cart Time                        0
# Purchased Date                        38238
# RFM Value                             21069
# Body height                           52811
# Readymade /kids /Bust size            19551
# Customer Last Purchased Date          21050
# Customer Last website Visited date    22055
# Customer Registered Date                  0
# Customer Name                             0
# City                                  17254
# State                                 18062
# ...

# %%
data["SKU's Unique Group ID"].value_counts()
# Out:
# SL     27266
# SA     10042
# GH      6008
# KR      3833
# IW      3662
# KP      3154
# SH      2023
# JY      1153
# BL       944
# ER       920
# KDG      813
# KDB      746
# DP       393
# WBE      285
# JK       267
# WB       169
# KF       127
# KU        59
# SU        32
# HJ        13
# AB        11
# HE         5
# HB         4
# FW         2
# Name: SKU's Unique Group ID, dtype: int64

# %%
data["Domain"].value_counts()
# Out:
# Global site    44066
# UK site         8424
# CA site         4946
# IN site         3457
# AU site          641
# ME site          397
# Name: Domain, dtype: int64

# %%
data["Art style"].value_counts()
# Out:
# Embroidered |                                          26047
# Printed |                                               4838
# Zari |                                                  1600
# Benarasi | Zari |                                       1578
# Embroidered | Zari |                                    1365
#                                                        ...
# Beads | Embroidered | Sequins | Zari |                     1
# Beads | Benarasi | Embroidered | Jacquard | Zari |         1
# Beads | Shimmer | Stones |                                 1
# Gota | Mirror work |                                       1
# Digital Print | Patch Work |                               1
# Name: Art style, Length: 359, dtype: int64

# %%
data["Product style"].value_counts()
# Out:
# Abaya Style |                                6642
# Anarkali Gown |                              1111
# Long Choli Lehenga |                          667
# Anarkali Lehengas | Long Choli Lehenga |      629
# Border Saree |                                514
#                                              ...
# Dhoti Set | Trendy |                            1
# Short Top |                                     1
# Jodhpuri Style |                                1
# Straight Pant Set | Trendy |                    1
# Cold Shoulder | Maxi Dress |                    1
# Name: Product style, Length: 100, dtype: int64

# %%
data.drop(columns =["Customer Name","Customer Registered Date","Customer ID","City","State","Country","Added to Cart Date","Added to Cart Time","Customer Last website Visited date"],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61931 entries, 0 to 61930
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Domain                            61931 non-null  object
#  1   SKU                               61931 non-null  object
#  2   SKU's Unique Group ID             61931 non-null  object
#  3   Sku's Unique group Id Definition  61931 non-null  object
#  4   brand Name                        61931 non-null  object
#  5   Type                              61931 non-null  object
#  6   Art style                         56198 non-null  object
#  7   Product style                     13508 non-null  object
#  8   Purchased Date                    23693 non-null  object
#  9   RFM Value                         40862 non-null  object
#  10  Body height                       9120 non-null   float64
# ...

# %%
data.shape
# Out:
# (61931, 30)

# %%
data.head()
# Out:
#         Domain          SKU  SKU's Unique Group ID  \
# 0  Global site  SLSSITAI1001                    SL
# 1  Global site     KDSLP8113                   KDG
# 2  Global site     GHSMV6512                    GH
# 3  Global site    KRSVFKU277                    KR
# 4  Global site    KRSVFKU265                    KR
#
#   Sku's Unique group Id Definition brand Name              Type  \
# 0                    Salwar Kameez     Market     Churidar Suit
# 1                            Girls     Market   Girls Skirt Set
# 2                         Lehengas     Market  Fish Cut Lehenga
# 3                           Kurtis     Market        Long Kurti
# 4                           Kurtis     Market        Long Kurti
#
#                          Art style Product style Purchased Date RFM Value  \
# 0                   Embroidered |            NaN            NaN       NaN
# 1  Beads | Embroidered | Stones |            NaN            NaN       NaN
# ...

# %%
data["Product style"].mode()
# Out:
# 0    Abaya Style |
# Name: Product style, dtype: object

# %%
data_copy = data
data_copy.shape
# Out:
# (61931, 30)

# %%
data_copy.columns
# Out:
# Index(['Domain', 'SKU ', 'SKU's Unique Group ID',
#        'Sku's Unique group Id Definition', 'brand Name', 'Type', 'Art style',
#        'Product style', 'Purchased Date', 'RFM Value', 'Body height',
#        'Readymade /kids /Bust size', 'Customer Last Purchased Date',
#        'Waist To Floor size', 'Front Neck Style', 'Back Neck Style',
#        'Sleeve Style', 'Kameez Style', 'Pant Style', 'KameezLength',
#        'SleeveLength', 'Waist Type', 'Blouse Type', 'Blouse Length',
#        'Blouse Pattern', 'Blouse NeckStyle', 'Blouse BrassierSize',
#        'Blouse Front NeckDesign', 'Blouse back NeckDesign',
#        'Blouse SleeveDesign'],
#       dtype='object')

# %%
num  = ["Body height","Waist To Floor size","SleeveLength","Blouse Length","Blouse NeckStyle"]

# %%
data_cat = data_copy.drop(num,axis=1)
data_num = data_copy[num]

# %%
data_num.isnull().sum()
# Out:
# Body height            52811
# Waist To Floor size    61374
# SleeveLength           61566
# Blouse Length          61676
# Blouse NeckStyle       61676
# dtype: int64

# %%
# data_cat = data_copy.drop(columns=num,axis=1)

# %%
# data_cat = data_copy

# %%
data_cat.columns
# Out:
# Index(['Domain', 'SKU ', 'SKU's Unique Group ID',
#        'Sku's Unique group Id Definition', 'brand Name', 'Type', 'Art style',
#        'Product style', 'Purchased Date', 'RFM Value',
#        'Readymade /kids /Bust size', 'Customer Last Purchased Date',
#        'Front Neck Style', 'Back Neck Style', 'Sleeve Style', 'Kameez Style',
#        'Pant Style', 'KameezLength', 'Waist Type', 'Blouse Type',
#        'Blouse Pattern', 'Blouse BrassierSize', 'Blouse Front NeckDesign',
#        'Blouse back NeckDesign', 'Blouse SleeveDesign'],
#       dtype='object')

# %%
data_cat.shape
# Out:
# (61931, 25)

# %%
cat_columns = data_cat.columns

# %%
cat_columns
# Out:
# Index(['Domain', 'SKU ', 'SKU's Unique Group ID',
#        'Sku's Unique group Id Definition', 'brand Name', 'Type', 'Art style',
#        'Product style', 'Purchased Date', 'RFM Value',
#        'Readymade /kids /Bust size', 'Customer Last Purchased Date',
#        'Front Neck Style', 'Back Neck Style', 'Sleeve Style', 'Kameez Style',
#        'Pant Style', 'KameezLength', 'Waist Type', 'Blouse Type',
#        'Blouse Pattern', 'Blouse BrassierSize', 'Blouse Front NeckDesign',
#        'Blouse back NeckDesign', 'Blouse SleeveDesign'],
#       dtype='object')

# %%
for col in cat_columns:
    print(col)
# Out:
# Domain
# SKU
# SKU's Unique Group ID
# Sku's Unique group Id Definition
# brand Name
# Type
# Art style
# Product style
# Purchased Date
# RFM Value
# Readymade /kids /Bust size
# Customer Last Purchased Date
# Front Neck Style
# Back Neck Style
# Sleeve Style
# Kameez Style
# Pant Style
# KameezLength
# Waist Type
# Blouse Type
# Blouse Pattern
# Blouse BrassierSize
# Blouse Front NeckDesign
# Blouse back NeckDesign
# Blouse SleeveDesign

# %%
for col in cat_columns:
    if data_cat[col].isnull().sum() != 0 :
        freq = data_cat[col].value_counts().index[0]
        data_cat[col] = data_cat[col].fillna(freq)

# %%
data_cat.isnull().sum()
# Out:
# Domain                              0
# SKU                                 0
# SKU's Unique Group ID               0
# Sku's Unique group Id Definition    0
# brand Name                          0
# Type                                0
# Art style                           0
# Product style                       0
# Purchased Date                      0
# RFM Value                           0
# Readymade /kids /Bust size          0
# Customer Last Purchased Date        0
# Front Neck Style                    0
# Back Neck Style                     0
# Sleeve Style                        0
# Kameez Style                        0
# Pant Style                          0
# KameezLength                        0
# Waist Type                          0
# Blouse Type                         0
# Blouse Pattern                      0
# Blouse BrassierSize                 0
# Blouse Front NeckDesign             0
# Blouse back NeckDesign              0
# Blouse SleeveDesign                 0
# ...

# %%
data_num.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 data_num.isnull().sum()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isnull'

# %%
#21.10.2022

from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy="median")
impute.fit(data_num)
# Out:
# SimpleImputer(strategy='median')

# %%
data_num = impute.transform(data_num)

# %%
from sklearn.preprocessing import OneHotEncoder

encode = OneHotEncoder()
data_cat_encode = encode.fit_transform(data_cat)

# %%
print(encode.categories_)
# Out:
# [array(['AU site', 'CA site', 'Global site', 'IN site', 'ME site',
#        'UK site'], dtype=object), array(['AB43H071622', 'AB43H071648', 'ANKMTRATA17', ..., 'WBPAT092',
#        'WBPAT093', 'WBPAT106'], dtype=object), array(['AB', 'BL', 'DP', 'ER', 'FW', 'GH', 'HB', 'HE', 'HJ', 'IW', 'JK',
#        'JY', 'KDB', 'KDG', 'KF', 'KP', 'KR', 'KU', 'SA', 'SH', 'SL', 'SU',
#        'WB', 'WBE'], dtype=object), array(['Bags and Clutches', 'Boys', 'Ear Rings', 'Foot Jewellery',
#        'Girls', 'Hand Jewellery', 'Head Accessories', 'Head Jewellery',
#        'Indo Western', 'Islamic wear', 'Jackets', 'Kurta Pyjamas',
#        'Kurta Sets', 'Kurtis', 'Leggings and Bottoms', 'Lehengas',
#        'Men Footwear', 'Men Mix and Match', 'Neck Jewellery',
#        'Salwar Kameez', 'Sarees', 'Sherwanis', 'Suits', 'Teenage Boys',
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('impute',SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler()),
])

data_num_tr  = num_pipeline.fit_transform(data_num)

# %%
from sklearn.compose import ColumnTransformer


full_pipeline = ColumnTransformer([
    ("num",num_pipeline,num),
    ("cat",OneHotEncoder(),cat_columns),
])

data_prepared = full_pipeline.fit_transform(data)

# data.columns

# %%
data_cat.columns
# Out:
# Index(['Domain', 'SKU ', 'SKU's Unique Group ID',
#        'Sku's Unique group Id Definition', 'brand Name', 'Type', 'Art style',
#        'Product style', 'Purchased Date', 'RFM Value',
#        'Readymade /kids /Bust size', 'Customer Last Purchased Date',
#        'Front Neck Style', 'Back Neck Style', 'Sleeve Style', 'Kameez Style',
#        'Pant Style', 'KameezLength', 'Waist Type', 'Blouse Type',
#        'Blouse Pattern', 'Blouse BrassierSize', 'Blouse Front NeckDesign',
#        'Blouse back NeckDesign', 'Blouse SleeveDesign'],
#       dtype='object')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,random_state=2).fit(data_prepared)
kmeans
# Out:
# KMeans(n_clusters=3, random_state=2)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 1.10451491e-01  6.01112627e-02  5.99348299e-04 ...  2.90073679e-05
#    8.99228404e-04  9.84829147e-01]
#  [-1.37069630e-01  5.57451023e-02 -7.54050131e-04 ...  0.00000000e+00
#    0.00000000e+00  9.99449460e-01]
#  [-3.46471829e-01 -1.70194632e+01 -5.54897597e-04 ...  0.00000000e+00
#    0.00000000e+00  1.00000000e+00]]

# %%
kmeans.labels_
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
centroid = kmeans.cluster_centers_
label = kmeans.labels_

# %%
plt.scatter(centroid[:,0],centroid[:,1])
plt.show()
